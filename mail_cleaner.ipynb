# %%
import pandas as pd

# %%
df = pd.read_excel("mail.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0           SenderName                     SenderEmail  \
# 0           0         Aesha Dhakan        invitations@linkedin.com
# 1           1          Divy Sharma        invitations@linkedin.com
# 2           2  LinkedIn Job Alerts  jobalerts-noreply@linkedin.com
# 3           3  LinkedIn Job Alerts  jobalerts-noreply@linkedin.com
# 4           4             LinkedIn   messages-noreply@linkedin.com
#
#                                              Subject                    Date  \
# 0                                  I want to connect 1970-01-01 05:30:45.328
# 1                                  I want to connect 1970-01-01 05:30:45.328
# 2  “data scientist”: CLARA Analytics - Senior Dat... 1970-01-01 05:30:45.328
# 3  “data analyst”: The 1% Club - Data Analyst and... 1970-01-01 05:30:45.328
# 4                   GDSC-AIT mentioned you in a post 1970-01-01 05:30:45.328
#
#     Time                                            Payload
# 0  08:13  Aesha sent an invite. Respond now. Hi Jenil, I...
# 1  07:13  Divy, Cybersecurity Researcher at Ahmedabad Cy...
# 2  06:43  Your job alert for data scientist in United St...
# 3  06:43  Your job alert for data analyst in India 30 ne...
# 4  06:32  GDSC-AIT mentioned you in a post View: Join th...

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#             sendername                     senderemail  \
# 0         Aesha Dhakan        invitations@linkedin.com
# 1          Divy Sharma        invitations@linkedin.com
# 2  LinkedIn Job Alerts  jobalerts-noreply@linkedin.com
# 3  LinkedIn Job Alerts  jobalerts-noreply@linkedin.com
# 4             LinkedIn   messages-noreply@linkedin.com
#
#                                              subject                    date  \
# 0                                  I want to connect 1970-01-01 05:30:45.328
# 1                                  I want to connect 1970-01-01 05:30:45.328
# 2  “data scientist”: CLARA Analytics - Senior Dat... 1970-01-01 05:30:45.328
# 3  “data analyst”: The 1% Club - Data Analyst and... 1970-01-01 05:30:45.328
# 4                   GDSC-AIT mentioned you in a post 1970-01-01 05:30:45.328
#
#     time                                            payload
# 0  08:13  Aesha sent an invite. Respond now. Hi Jenil, I...
# 1  07:13  Divy, Cybersecurity Researcher at Ahmedabad Cy...
# 2  06:43  Your job alert for data scientist in United St...
# 3  06:43  Your job alert for data analyst in India 30 ne...
# 4  06:32  GDSC-AIT mentioned you in a post View: Join th...

# %%
df['date']
# Out:
# 0    1970-01-01 05:30:45.328
# 1    1970-01-01 05:30:45.328
# 2    1970-01-01 05:30:45.328
# 3    1970-01-01 05:30:45.328
# 4    1970-01-01 05:30:45.328
#                ...
# 95   1970-01-01 05:30:45.309
# 96   1970-01-01 05:30:45.309
# 97   1970-01-01 05:30:45.309
# 98   1970-01-01 05:30:45.309
# 99   1970-01-01 05:30:45.308
# Name: date, Length: 100, dtype: datetime64[ns]

# %%
df.head()
# Out:
#             sendername                     senderemail  \
# 0         Aesha Dhakan        invitations@linkedin.com
# 1          Divy Sharma        invitations@linkedin.com
# 2  LinkedIn Job Alerts  jobalerts-noreply@linkedin.com
# 3  LinkedIn Job Alerts  jobalerts-noreply@linkedin.com
# 4             LinkedIn   messages-noreply@linkedin.com
#
#                                              subject                    date  \
# 0                                  I want to connect 1970-01-01 05:30:45.328
# 1                                  I want to connect 1970-01-01 05:30:45.328
# 2  “data scientist”: CLARA Analytics - Senior Dat... 1970-01-01 05:30:45.328
# 3  “data analyst”: The 1% Club - Data Analyst and... 1970-01-01 05:30:45.328
# 4                   GDSC-AIT mentioned you in a post 1970-01-01 05:30:45.328
#
#     time                                            payload
# 0  08:13  Aesha sent an invite. Respond now. Hi Jenil, I...
# 1  07:13  Divy, Cybersecurity Researcher at Ahmedabad Cy...
# 2  06:43  Your job alert for data scientist in United St...
# 3  06:43  Your job alert for data analyst in India 30 ne...
# 4  06:32  GDSC-AIT mentioned you in a post View: Join th...

# %%
df.head()
# Out:
#             sendername                     senderemail  \
# 0         Aesha Dhakan        invitations@linkedin.com
# 1          Divy Sharma        invitations@linkedin.com
# 2  LinkedIn Job Alerts  jobalerts-noreply@linkedin.com
# 3  LinkedIn Job Alerts  jobalerts-noreply@linkedin.com
# 4             LinkedIn   messages-noreply@linkedin.com
#
#                                              subject                    date  \
# 0                                  I want to connect 1970-01-01 05:30:45.328
# 1                                  I want to connect 1970-01-01 05:30:45.328
# 2  “data scientist”: CLARA Analytics - Senior Dat... 1970-01-01 05:30:45.328
# 3  “data analyst”: The 1% Club - Data Analyst and... 1970-01-01 05:30:45.328
# 4                   GDSC-AIT mentioned you in a post 1970-01-01 05:30:45.328
#
#     time                                            payload
# 0  08:13  Aesha sent an invite. Respond now. Hi Jenil, I...
# 1  07:13  Divy, Cybersecurity Researcher at Ahmedabad Cy...
# 2  06:43  Your job alert for data scientist in United St...
# 3  06:43  Your job alert for data analyst in India 30 ne...
# 4  06:32  GDSC-AIT mentioned you in a post View: Join th...

# %%
df['month'] = df.date.dt.month_name()

# %%
df['days'] = df.date.dt.day_name()

# %%
df['days'].unique()
# Out:
# array(['Thursday'], dtype=object)

# %%
df
# Out:
#                     sendername                         senderemail  \
# 0                 Aesha Dhakan            invitations@linkedin.com
# 1                  Divy Sharma            invitations@linkedin.com
# 2          LinkedIn Job Alerts      jobalerts-noreply@linkedin.com
# 3          LinkedIn Job Alerts      jobalerts-noreply@linkedin.com
# 4                     LinkedIn       messages-noreply@linkedin.com
# ..                         ...                                 ...
# 95           Akshat Khandelwal            invitations@linkedin.com
# 96            Maulik Mangukiya            invitations@linkedin.com
# 97                    LinkedIn       messages-noreply@linkedin.com
# 98  hod it (via Google Sheets)  drive-shares-dm-noreply@google.com
# 99              Dr Leena Patel            invitations@linkedin.com
#
#                                               subject                    date  \
# 0                                   I want to connect 1970-01-01 05:30:45.328
# 1                                   I want to connect 1970-01-01 05:30:45.328
# 2   “data scientist”: CLARA Analytics - Senior Dat... 1970-01-01 05:30:45.328
# 3   “data analyst”: The 1% Club - Data Analyst and... 1970-01-01 05:30:45.328
# 4                    GDSC-AIT mentioned you in a post 1970-01-01 05:30:45.328
# ..                                                ...                     ...
# 95      Jenil, please add me to your LinkedIn network 1970-01-01 05:30:45.309
# 96      Jenil, please add me to your LinkedIn network 1970-01-01 05:30:45.309
# 97                      Jenil, you’re getting noticed 1970-01-01 05:30:45.309
# 98  Spreadsheet shared with you: "8_IT_SUMMER_INTE... 1970-01-01 05:30:45.309
# 99      Jenil, please add me to your LinkedIn network 1970-01-01 05:30:45.308
#
#      time                                            payload    month  \
# 0   08:13  Aesha sent an invite. Respond now. Hi Jenil, I...  January
# 1   07:13  Divy, Cybersecurity Researcher at Ahmedabad Cy...  January
# 2   06:43  Your job alert for data scientist in United St...  January
# 3   06:43  Your job alert for data analyst in India 30 ne...  January
# 4   06:32  GDSC-AIT mentioned you in a post View: Join th...  January
# ..    ...                                                ...      ...
# 95  20:32  Hi Jenil Jani, Id like to join your LinkedIn n...  January
# 96  16:45  Hi Jenil Jani, Id like to join your LinkedIn n...  January
# 97  13:55  Your profile is looking great Your work and ac...  January
# 98  05:03  Ive shared an item with you: 8_IT_SUMMER_INTER...  January
# 99  18:43  Hi Jenil Jani, Id like to join your LinkedIn n...  January
#
#         days
# 0   Thursday
# 1   Thursday
# 2   Thursday
# 3   Thursday
# 4   Thursday
# ..       ...
# 95  Thursday
# 96  Thursday
# 97  Thursday
# 98  Thursday
# 99  Thursday
#
# [100 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['sendername', 'senderemail', 'subject', 'date', 'time', 'payload',
#        'month', 'days'],
#       dtype='object')
